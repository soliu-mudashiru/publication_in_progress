# %% [markdown]
# The following codes are used for the SVM model

# %%
import pandas as pd
# Load your cleaned dataset
df = pd.read_csv("Fact_BH_Val_Use.csv")
df.head(5)
# Out:
#        TWI  SLTYPE     SLOPE     RAINFALL    PTWBDS  LULC   LD  GEOMPLGY  \
# 0  7.38109       2  0.733701  2255.969971  0.008207     7  0.0         2
# 1  3.95345       2  2.074430  2262.219971  0.017312     7  0.0         2
# 2  3.51728       2  1.968060  2260.989990  0.007566     7  0.0         2
# 3  7.40654       2  1.391900  2274.969971  0.002595     7  0.0         2
# 4  3.91196       2  3.092650  2265.090088  0.014795     7  0.0         2
#
#    GEOLOGY       DD    NDVI  ELEVATION  SOILPERM       SPI       TRI  \
# 0        3  1.39622  0.5824        296         2  0.000000  0.566558
# 1        4  1.59473  0.3255        302         2 -2.625150  0.955814
# 2        3  1.35630  0.5724        292         2  0.000000  0.874890
# 3        3  1.32644  0.9025        275         2  1.993670  1.227260
# 4        4  1.58542  0.5529        324         2  0.026023  1.490710
#
#          ASPT
# 0   45.000000
# 1   98.130096
# 2  108.434998
# 3  296.565002
# 4  258.690002

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import pandas as pd

# Ensure that data is numeric and drop rows with NaN
df_clean = df.apply(pd.to_numeric, errors='coerce')  # Convert to numeric, non-numeric becomes NaN
df_clean = df_clean.dropna()  # Drop rows with NaN values

# Load your cleaned dataset
df = pd.read_csv("Fact_BH_Val_Use.csv")

# Add constant term for intercept
X = add_constant(df_clean)

# Compute VIF
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Show results
print(vif_data)
# Out:
#       Feature        VIF
# 0       const   8.982754
# 1         TWI   5.023303
# 2      SLTYPE        inf
# 3       SLOPE  32.696450
# 4    RAINFALL  19.883482
# 5      PTWBDS   4.022180
# 6        LULC   7.943325
# 7          LD   1.950327
# 8    GEOMPLGY  15.985908
# 9     GEOLOGY   3.423483
# 10         DD   3.852324
# 11       NDVI   2.509862
# 12  ELEVATION  11.495330
# 13   SOILPERM        inf
# 14        SPI   2.658435
# 15        TRI  37.031940
# 16       ASPT   2.317432
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = X.corr()
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import pandas as pd

# Ensure that data is numeric and drop rows with NaN
df_clean = df.apply(pd.to_numeric, errors='coerce')  # Convert to numeric, non-numeric becomes NaN
df_clean = df_clean.dropna()  # Drop rows with NaN values

# Load your cleaned dataset
df = pd.read_csv("Fact_BH_Val_Use_2.csv")

# Add constant term for intercept
X = add_constant(df_clean)

# Compute VIF
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Show results
print(vif_data)
# Out:
#      Feature        VIF
# 0      const   8.937508
# 1        TWI   3.675788
# 2     SLTYPE   3.245031
# 3      SLOPE   2.419079
# 4   RAINFALL  12.480517
# 5     PTWBDS   3.296960
# 6       LULC   5.441096
# 7         LD   1.790974
# 8   GEOMPLGY   5.694264
# 9    GEOLOGY   2.772483
# 10        DD   2.833906
# 11      NDVI   2.212632
# 12      ASPT   2.015809

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = X.corr()
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import pandas as pd

# Ensure that data is numeric and drop rows with NaN
df_clean = df.apply(pd.to_numeric, errors='coerce')  # Convert to numeric, non-numeric becomes NaN
df_clean = df_clean.dropna()  # Drop rows with NaN values

# Load your cleaned dataset
df = pd.read_csv("Fact_BH_Val_Use_3.csv")

# Add constant term for intercept
X = add_constant(df_clean)

# Compute VIF
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Show results
print(vif_data)
# Out:
#     Feature       VIF
# 0     const  8.896936
# 1       TWI  3.131640
# 2  RAINFALL  6.685973
# 3    PTWBDS  2.229889
# 4        LD  1.513216
# 5   GEOLOGY  2.227464
# 6        DD  2.627588
# 7      NDVI  2.190951
# 8      ASPT  1.912821
# 9     SLOPE  1.653954

# %%
# Compute tolerance by taking the reciprocal of VIF
vif_data["Tolerance"] = 1 / vif_data["VIF"]

# Show results
print(vif_data)
# Out:
#     Feature       VIF  Tolerance
# 0     const  8.896936   0.112398
# 1       TWI  3.131640   0.319321
# 2  RAINFALL  6.685973   0.149567
# 3    PTWBDS  2.229889   0.448453
# 4        LD  1.513216   0.660844
# 5   GEOLOGY  2.227464   0.448941
# 6        DD  2.627588   0.380577
# 7      NDVI  2.190951   0.456423
# 8      ASPT  1.912821   0.522788
# 9     SLOPE  1.653954   0.604612

# %%
# Create a DataFrame
df = pd.DataFrame(vif_data)

df.to_excel('vif_data_tol.xlsx', index = False)

# %%
df
# Out:
#     Feature       VIF  Tolerance
# 0     const  8.896936   0.112398
# 1       TWI  3.131640   0.319321
# 2  RAINFALL  6.685973   0.149567
# 3    PTWBDS  2.229889   0.448453
# 4        LD  1.513216   0.660844
# 5   GEOLOGY  2.227464   0.448941
# 6        DD  2.627588   0.380577
# 7      NDVI  2.190951   0.456423
# 8      ASPT  1.912821   0.522788
# 9     SLOPE  1.653954   0.604612

# %%
# for training and prediction
# for training and prediction

import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load training data
df = pd.read_csv("Fact_BH_Val_Use_New.csv")

# Encode class labels (replace 'remarks' with your actual label column name)
label_encoder = LabelEncoder()
df['class_encoded'] = label_encoder.fit_transform(df['Remark'])  # <- change this if needed

# Drop non-numeric columns except the target
X = df.drop(columns=['remarks', 'class_encoded'], errors='ignore')
X = X.select_dtypes(include='number')  # <-- This keeps only numeric features
y = df['class_encoded']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train SVM model
svm_model = SVC(kernel='rbf', probability=True, random_state=42)
svm_model.fit(X_scaled, y)

# Load fishnet (prediction) data
fishnet_df = pd.read_csv("Factr_Fish_Val_Use_New.csv")
X_fishnet = fishnet_df.select_dtypes(include='number')  # Keep only numeric columns

# Apply same scaling
X_fishnet_scaled = scaler.transform(X_fishnet)

# Predict class and probabilities
fishnet_df['svm_pred_class'] = svm_model.predict(X_fishnet_scaled)

# Predict class probabilities
probs = svm_model.predict_proba(X_fishnet_scaled)
for i, class_name in enumerate(label_encoder.classes_):
    fishnet_df[f'svm_prob_{class_name.lower()}'] = probs[:, i]

# Save predictions
fishnet_df.to_csv("fishnet_svm_predictions_new.csv", index=False)

### The code run and generated the right result

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from collections import Counter

# Load training data
df = pd.read_csv("Fact_BH_Val_Use_New.csv")

# Encode class labels
label_encoder = LabelEncoder()
df['class_encoded'] = label_encoder.fit_transform(df['Remark'])  # Ensure 'Remark' exists

# Drop non-numeric columns except the target
X = df.drop(columns=['Remark', 'class_encoded'], errors='ignore')
X = X.select_dtypes(include='number')
y = df['class_encoded']

# Check class distribution
print("Training class distribution:", Counter(y))

# Train-test split with stratification for validation
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the SVM model with balanced class weight
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', class_weight='balanced', probability=True, random_state=42)
svm_model.fit(X_train_scaled, y_train)

# Predict on test set
y_pred = svm_model.predict(X_test_scaled)

# Evaluate model
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Check predicted classes
print("\nUnique predicted classes in test set:", set(y_pred))

# ----------- PREDICTION ON FISHNET DATA ----------- #
# Load fishnet (prediction) data
fishnet_df = pd.read_csv("Factr_Fish_Val_Use_New.csv")
X_fishnet = fishnet_df.select_dtypes(include='number')

# Apply the same scaling
X_fishnet_scaled = scaler.transform(X_fishnet)

# Predict class and probabilities
fishnet_df['svm_pred_class'] = svm_model.predict(X_fishnet_scaled)

# Predict probabilities
probs = svm_model.predict_proba(X_fishnet_scaled)
for i, class_name in enumerate(label_encoder.classes_):
    fishnet_df[f'svm_prob_{class_name.lower()}'] = probs[:, i]

# Save fishnet predictions
fishnet_df.to_csv("fishnet_svm_predictions_new_2.csv", index=False)
# Out:
# Training class distribution: Counter({2: 15, 0: 12, 1: 9})
#
# Confusion Matrix:
#  [[2 0 1]
#  [0 0 2]
#  [0 0 3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.00      0.00      0.00         2
#            2       0.50      1.00      0.67         3
#
#     accuracy                           0.62         8
#    macro avg       0.50      0.56      0.49         8
# weighted avg       0.56      0.62      0.55         8
#
#
# Unique predicted classes in test set: {0, 2}
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pip install imbalanced-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting imbalanced-learn
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\USER\\anaconda3\\Lib\\site-packages\\~klearn\\decomposition\\_cdnmf_fast.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (2.1.0)
# Collecting scikit-learn>=1.0.2
#   Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.19.2)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib, scikit-learn, imbalanced-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.17.0
#     Uninstalling joblib-0.17.0:
#       Successfully uninstalled joblib-0.17.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2

# %%
pip install imbalanced-learn --user
# Out:
# Collecting imbalanced-learnNote: you may need to restart the kernel to use updated packages.
#   Using cached imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (2.1.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
#
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.12.4

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\user\appdata\roaming\python\python38\site-packages (0.12.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (2.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from collections import Counter

# Load training data
df = pd.read_csv("Fact_BH_Val_Use_New.csv")

# Encode class labels
label_encoder = LabelEncoder()
df['class_encoded'] = label_encoder.fit_transform(df['Remark'])

# Drop non-numeric columns
X = df.drop(columns=['Remark', 'class_encoded'], errors='ignore')
X = X.select_dtypes(include='number')
y = df['class_encoded']

# Check class distribution before balancing
print("Original class distribution:", Counter(y))

# Split before applying SMOTE to avoid data leakage
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

# Apply SMOTE to training set only
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

# Check class distribution after SMOTE
print("Balanced class distribution:", Counter(y_train_bal))

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_bal)
X_test_scaled = scaler.transform(X_test)

# Train SVM model
svm_model = SVC(kernel='rbf', class_weight='balanced', probability=True, random_state=42)
svm_model.fit(X_train_scaled, y_train_bal)

# Evaluate on test set
y_pred = svm_model.predict(X_test_scaled)
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nPredicted classes in test set:", set(y_pred))

# ----------- PREDICTION ON FISHNET DATA ----------- #
# Load fishnet data
fishnet_df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")
X_fishnet = fishnet_df.select_dtypes(include='number')

# Scale using same scaler
X_fishnet_scaled = scaler.transform(X_fishnet)

# Predict class and probabilities
fishnet_df['svm_pred_class'] = svm_model.predict(X_fishnet_scaled)
probs = svm_model.predict_proba(X_fishnet_scaled)
for i, class_name in enumerate(label_encoder.classes_):
    fishnet_df[f'svm_prob_{class_name.lower()}'] = probs[:, i]

# Save results
fishnet_df.to_csv("fishnet_svm_predictions_fixed.csv", index=False)
print("✔️ Fishnet predictions with SMOTE-balanced SVM saved.")
# Out:
# Original class distribution: Counter({2: 15, 0: 12, 1: 9})
# Balanced class distribution: Counter({1: 12, 0: 12, 2: 12})
#
# Confusion Matrix:
#  [[2 0 1]
#  [0 0 2]
#  [0 0 3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.00      0.00      0.00         2
#            2       0.50      1.00      0.67         3
#
#     accuracy                           0.62         8
#    macro avg       0.50      0.56      0.49         8
# weighted avg       0.56      0.62      0.55         8
#
#
# Predicted classes in test set: {0, 2}
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✔️ Fishnet predictions with SMOTE-balanced SVM saved.

# %%
# validating svm model

import pandas as pd
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, confusion_matrix, roc_auc_score
)
from sklearn.preprocessing import label_binarize

# Load CSV
df = pd.read_csv("Data_4_Val_SVM.csv")

# Extract true and predicted labels
y_true = df['Actual']
y_pred = df['Predicted']

# Print classification report
print("=== Classification Report ===")
print(classification_report(y_true, y_pred))

# Confusion matrix
print("=== Confusion Matrix ===")
print(confusion_matrix(y_true, y_pred))

# Accuracy
print("Accuracy:", accuracy_score(y_true, y_pred))
print("Precision (macro):", precision_score(y_true, y_pred, average='macro'))
print("Recall (macro):", recall_score(y_true, y_pred, average='macro'))
print("F1 Score (macro):", f1_score(y_true, y_pred, average='macro'))

# ROC AUC (for multiclass with probabilities)
# Make sure the probabilities exist
if 'Prob_0' in df.columns:
    classes = sorted(y_true.unique())
    y_true_bin = label_binarize(y_true, classes=classes)
    y_score = df[[f'Prob_{cls}' for cls in classes]]

    auc = roc_auc_score(y_true_bin, y_score, average='macro', multi_class='ovr')
    print("AUC-ROC (macro, OvR):", auc)
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        60
#            1       0.50      0.26      0.34       112
#            2       0.21      0.57      0.31        53
#
#     accuracy                           0.26       225
#    macro avg       0.24      0.27      0.22       225
# weighted avg       0.30      0.26      0.24       225
#
# === Confusion Matrix ===
# [[ 0 25 35]
#  [ 8 29 75]
#  [19  4 30]]
# Accuracy: 0.26222222222222225
# Precision (macro): 0.2380952380952381
# Recall (macro): 0.2749887690925427
# F1 Score (macro): 0.21735243320125983

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split

# Load your CSV
df = pd.read_csv("Data_4_Val_SVM.csv")

# Extract actual and predicted probabilities
y_true = df["Actual"]
classes = sorted(y_true.unique())  # Example: [0, 1, 2]
n_classes = len(classes)

# Binarize the actual classes
y_test_bin = label_binarize(y_true, classes=classes)

# Predicted probabilities: Ensure your CSV has Prob_0, Prob_1, ..., Prob_n
y_score = df[[f'Prob_{cls}' for cls in classes]]

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score.iloc[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute macro-average ROC curve and AUC
fpr["macro"], tpr["macro"], _ = roc_curve(y_test_bin.ravel(), y_score.values.ravel())
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot
plt.figure(figsize=(10, 6))
colors = ['blue', 'green', 'red', 'orange', 'purple']

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f"Class {classes[i]} (AUC = {roc_auc[i]:.2f})")

# Macro-average ROC
plt.plot(fpr["macro"], tpr["macro"], color='navy', linestyle='--',
         label=f"Macro-average (AUC = {roc_auc['macro']:.2f})", linewidth=2)

plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multiclass ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from itertools import cycle

# Load the data
df = pd.read_csv("all_ml_models_val_data.csv")

# Get true classes
y_true = df['Actual']
classes = sorted(y_true.unique())
y_test_bin = label_binarize(y_true, classes=classes)

# Define models and their respective probability columns
models = {
    'SVM': ['SVM_0', 'SVM_1', 'SVM_2'],
    'RF': ['RF_0', 'RF_1', 'RF_2'],
    'XGBoost': ['XGB_0', 'XGB_1', 'XGB_2'],
    'AdaBoost': ['ADA_0', 'ADA_1', 'ADA_2']
}

# Plot setup
plt.figure(figsize=(10, 7))

# Colors
colors = cycle(['blue', 'green', 'darkorange', 'red'])

for model_name, color in zip(models.keys(), colors):
    y_score = df[models[model_name]].values

    # Compute ROC curve and ROC area using micro-averaging
    fpr, tpr, _ = roc_curve(y_test_bin.ravel(), y_score.ravel())
    roc_auc = auc(fpr, tpr)

    # Plot
    plt.plot(fpr, tpr, color=color, lw=2,
             label=f'{model_name} (AUC = {roc_auc:.2f})')

# Plot settings
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('Micro-Averaged ROC Curve (Multi-Class)', fontsize=14)
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# The following codes are for RF model

# %%
# for training and prediction
# for training and prediction

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load training data
df = pd.read_csv("Fact_BH_Val_Use_New.csv")

# Encode class labels
label_encoder = LabelEncoder()
df['class_encoded'] = label_encoder.fit_transform(df['Remark'])

# Drop non-numeric columns except target
X = df.drop(columns=['remarks', 'class_encoded'], errors='ignore')
X = X.select_dtypes(include='number')
y = df['class_encoded']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_scaled, y)

# Predict on fishnet data
fishnet_df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")
X_fishnet = fishnet_df.select_dtypes(include='number')
X_fishnet_scaled = scaler.transform(X_fishnet)

# Predict classes
fishnet_df['rf_pred_class'] = rf_model.predict(X_fishnet_scaled)

# Predict probabilities
probs = rf_model.predict_proba(X_fishnet_scaled)
for i, class_name in enumerate(label_encoder.classes_):
    fishnet_df[f'rf_prob_{class_name.lower()}'] = probs[:, i]

# Save output
fishnet_df.to_csv("fishnet_rf_predictions_new_crct_now.csv", index=False)

### The code run and generated the right result

# %% [markdown]
# The following codes are for XGBoost

# %%
# for training and prediction
# for training and prediction

import pandas as pd
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load and encode
df = pd.read_csv("Fact_BH_Val_Use_New.csv")
label_encoder = LabelEncoder()
df['class_encoded'] = label_encoder.fit_transform(df['Remark'])

X = df.drop(columns=['remarks', 'class_encoded'], errors='ignore').select_dtypes(include='number')
y = df['class_encoded']

# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train XGBoost
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
xgb_model.fit(X_scaled, y)

# Predict
fishnet_df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")
X_fishnet = fishnet_df.select_dtypes(include='number')
X_fishnet_scaled = scaler.transform(X_fishnet)

fishnet_df['xgb_pred_class'] = xgb_model.predict(X_fishnet_scaled)
probs = xgb_model.predict_proba(X_fishnet_scaled)
for i, class_name in enumerate(label_encoder.classes_):
    fishnet_df[f'xgb_prob_{class_name.lower()}'] = probs[:, i]

# Save
fishnet_df.to_csv("fishnet_xgb_predictions_new_crct_now_now.csv", index=False)

### The code run and generated the right result
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")

# %%
# fine tuning xgboost model
import pandas as pd
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# Load and encode data
df = pd.read_csv("Fact_BH_Val_Use_New.csv")
label_encoder = LabelEncoder()
df['class_encoded'] = label_encoder.fit_transform(df['Remark'])

X = df.drop(columns=['remarks', 'class_encoded'], errors='ignore').select_dtypes(include='number')
y = df['class_encoded']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split for grid search validation
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [100, 200],  # Number of boosting rounds
    'max_depth': [3, 5, 7],  # Maximum depth of a tree
    'learning_rate': [0.05, 0.1, 0.2],  # Learning rate
    'subsample': [0.7, 1.0],  # Fraction of samples used for each tree
    'colsample_bytree': [0.7, 1.0]  # Fraction of features used for each tree
}

# Initialize the XGBoost model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    scoring='roc_auc_ovr',  # ROC AUC for multiclass
    cv=3,  # 3-fold cross-validation
    verbose=1,
    n_jobs=-1
)

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Best parameters found by GridSearchCV
print("✅ Best parameters found:", grid_search.best_params_)

# Use the best model to predict on the test set
best_model = grid_search.best_estimator_
y_probs = best_model.predict_proba(X_test)

# Calculate ROC AUC score for multiclass
auc_score = roc_auc_score(y_test, y_probs, multi_class='ovr', average='micro')
print("📈 Micro-averaged ROC AUC after tuning:", round(auc_score * 100, 2), "%")

# Now predicting on the fishnet data
fishnet_df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")
X_fishnet = fishnet_df.select_dtypes(include='number')
X_fishnet_scaled = scaler.transform(X_fishnet)

# Predict class and probabilities for fishnet data
fishnet_df['xgb_pred_class'] = best_model.predict(X_fishnet_scaled)
probs = best_model.predict_proba(X_fishnet_scaled)

# Assign probabilities to respective class columns
for i, class_name in enumerate(label_encoder.classes_):
    fishnet_df[f'xgb_prob_{class_name.lower()}'] = probs[:, i]

# Save the predictions to a new CSV file
fishnet_df.to_csv("fishnet_xgb_predictions_tuned.csv", index=False)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\USER\anaconda3\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# C:\Users\USER\anaconda3\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# ✅ Best parameters found: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.7}
# 📈 Micro-averaged ROC AUC after tuning: 77.27 %

# %%
# for training and prediction
# for training and prediction

import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load and encode
df = pd.read_csv("Fact_BH_Val_Use_New.csv")
label_encoder = LabelEncoder()
df['class_encoded'] = label_encoder.fit_transform(df['Remark'])

X = df.drop(columns=['remarks', 'class_encoded'], errors='ignore').select_dtypes(include='number')
y = df['class_encoded']

# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train AdaBoost
ada_model = AdaBoostClassifier(n_estimators=100, random_state=42)
ada_model.fit(X_scaled, y)

# Predict
fishnet_df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")
X_fishnet = fishnet_df.select_dtypes(include='number')
X_fishnet_scaled = scaler.transform(X_fishnet)

fishnet_df['ada_pred_class'] = ada_model.predict(X_fishnet_scaled)
probs = ada_model.predict_proba(X_fishnet_scaled)
for i, class_name in enumerate(label_encoder.classes_):
    fishnet_df[f'ada_prob_{class_name.lower()}'] = probs[:, i]

# Save
fishnet_df.to_csv("fishnet_ada_predictions_new_crct.csv", index=False)

### The code run and generated the right result

# %% [markdown]
# The following codes are for generating the AHP model result

# %%
# import the necessary libraries

import numpy as np
import pandas as pd

# Read the pairwise comparison matrix as a CSV file and convert to numpy array

pairwise_matrix = pd.read_csv('Consolidated_AHP_Pairwise_Matrix.csv', index_col=0).values

# Square the Pairwise Comparison Matrix
squared_matrix = np.dot(pairwise_matrix, pairwise_matrix)

# Normalize the Squared Pairwise Comparison Matrix
column_sums = np.sum(squared_matrix, axis=0)  # Column-wise sum
normalized_matrix = squared_matrix / column_sums  # Normalize each column

# Compute Row Sums of the Normalized Matrix
row_sums = np.sum(normalized_matrix, axis=1)

# Calculate Criteria Weights
criteria_weights = row_sums / np.sum(row_sums)

# Consistency Check
# Multiply the original matrix by the weights vector
weighted_sum_vector = np.dot(pairwise_matrix, criteria_weights)

# Compute the consistency vector
consistency_vector = weighted_sum_vector / criteria_weights

# Calculate lambda_max
lambda_max = np.mean(consistency_vector)

# Number of criteria (n) and Random Index (RI) values
n = pairwise_matrix.shape[0]
RI_values = {1: 0, 2: 0, 3: 0.58, 4: 0.9, 5: 1.12, 6: 1.24, 7: 1.32, 8: 1.41, 9: 1.45, 10: 1.49}
RI = RI_values.get(n, 1.49)  # Default to max RI if n > 10

# Consistency Index (CI) and Consistency Ratio (CR)
CI = (lambda_max - n) / (n - 1)
CR = CI / RI if RI != 0 else 0

# Output results
print("Pairwise Comparison Matrix (Original):")
print(pairwise_matrix)
print("\nSquared Pairwise Comparison Matrix:")
print(squared_matrix)
print("\nNormalized Matrix:")
print(normalized_matrix)
print("\nCriteria Weights:")
print(criteria_weights)
print ("\nlambda_max:")
print(lambda_max)
print("\nConsistency Index:")
print(CI)
print(f"\nConsistency Ratio (CR): {CR:.4f}")
# Out:
# Pairwise Comparison Matrix (Original):
# [[1.    0.5   2.    0.5   0.333 1.    3.    5.    5.   ]
#  [2.    1.    3.    1.    0.5   2.    5.    7.    7.   ]
#  [0.5   0.333 1.    0.333 0.25  0.5   2.    4.    4.   ]
#  [2.    1.    3.    1.    0.5   2.    5.    7.    7.   ]
#  [3.    2.    4.    2.    1.    3.    6.    8.    8.   ]
#  [1.    0.5   2.    0.5   0.333 1.    3.    5.    5.   ]
#  [0.333 0.2   0.5   0.2   0.167 0.333 1.    3.    3.   ]
#  [0.2   0.143 0.25  0.143 0.125 0.2   0.333 1.    2.   ]
#  [0.2   0.143 0.25  0.143 0.125 0.2   0.333 0.5   1.   ]]
#
# Squared Pairwise Comparison Matrix:
# [[  8.998      5.362     14.332      5.362      3.75       8.998
#    23.328     44.164     51.664   ]
#  [ 15.465      9.001     25.         9.001      6.167     15.465
#    40.662     75.5       86.      ]
#  [  5.848      3.543      8.998      3.543      2.5        5.848
#    14.494     27.662     33.662   ]
#  [ 15.465      9.001     25.         9.001      6.167     15.465
#    40.662     75.5       86.      ]
#  [ 24.198     13.82      39.        13.82       9.        24.198
#    63.328    112.       124.      ]
#  [  8.998      5.362     14.332      5.362      3.75       8.998
#    23.328     44.164     51.664   ]
#  [  3.75       2.2915     5.7        2.2915     1.630778   3.75
#     8.998     16.966     21.466   ]
#  [  2.182889   1.31485    3.3245     1.31485    0.894311   2.182889
#     5.212      9.001     11.001   ]
#  [  1.882889   1.10035    2.9495     1.10035    0.706811   1.882889
#     4.7125     8.001      9.001   ]]
#
# Normalized Matrix:
# [[0.10367819 0.10556012 0.10337863 0.10556012 0.10848842 0.10367819
#   0.10380711 0.1069455  0.10889057]
#  [0.17819329 0.17720004 0.18032834 0.17720004 0.17841283 0.17819329
#   0.18094155 0.18282731 0.18125946]
#  [0.06738276 0.06975    0.06490378 0.06975    0.07232562 0.06738276
#   0.06449675 0.06698502 0.07094832]
#  [0.17819329 0.17720004 0.18032834 0.17720004 0.17841283 0.17819329
#   0.18094155 0.18282731 0.18125946]
#  [0.27881806 0.27207027 0.28131221 0.27207027 0.26037222 0.27881806
#   0.28180283 0.27121402 0.26135085]
#  [0.10367819 0.10556012 0.10337863 0.10556012 0.10848842 0.10367819
#   0.10380711 0.1069455  0.10889057]
#  [0.04320885 0.04511209 0.04111486 0.04511209 0.04717881 0.04320885
#   0.04004014 0.04108408 0.0452432 ]
#  [0.02515203 0.02588507 0.02398006 0.02588507 0.02587264 0.02515203
#   0.02319284 0.02179641 0.02318646]
#  [0.02169532 0.02166227 0.02127514 0.02166227 0.02044822 0.02169532
#   0.02097012 0.01937485 0.01897112]]
#
# Criteria Weights:
# [0.10555409 0.17939513 0.06821389 0.17939513 0.27309209 0.10555409
#  0.04347811 0.02445584 0.02086163]
#
# lambda_max:
# 9.229329942531331
#
# Consistency Index:
# 0.028666242816416387
#
# Consistency Ratio (CR): 0.0198

# %%
import pandas as pd

# Assuming you have the following NumPy arrays:
# pairwise_matrix, squared_matrix, normalized_matrix, criteria_weights, CR

# You can use your criteria names for column and index labels if available
criteria_names = [
    'TWI', 'RAINFALL', 'Proximity to surface water bodies', 
    'Lineament density', 'Geology', 'Drainage density', 
    'NDVI', 'Aspect', 'Slope'
]

# Convert to DataFrames with correct labels
pairwise_df = pd.DataFrame(pairwise_matrix, index=criteria_names, columns=criteria_names)
squared_df = pd.DataFrame(squared_matrix, index=criteria_names, columns=criteria_names)
normalized_df = pd.DataFrame(normalized_matrix, index=criteria_names, columns=criteria_names)
weights_df = pd.DataFrame({'Criteria': criteria_names, 'Weight': criteria_weights})

# Export to Excel
with pd.ExcelWriter("ahp_results_now.xlsx", engine="xlsxwriter") as writer:
    pairwise_df.to_excel(writer, sheet_name='Pairwise Matrix')
    squared_df.to_excel(writer, sheet_name='Squared Matrix')
    normalized_df.to_excel(writer, sheet_name='Normalized Matrix')
    weights_df.to_excel(writer, sheet_name='Criteria Weights', index=False)
    
print("Excel file 'ahp_results.xlsx' exported successfully.")
# Out:
# Excel file 'ahp_results.xlsx' exported successfully.

# %%
# converting the fishnet values into rating
# rating needed for further computations of AHP

import pandas as pd

# Load the fishnet input
df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")

# Rating functions using actual value intervals
def rate_twi(x):
    if -0.782 <= x <= 3.371: return 1
    elif 3.371 <= x <= 5.41: return 2
    elif 5.41 <= x <= 8.733: return 3
    elif 8.733 <= x <= 18.475: return 4
    else: return 1

def rate_rainfall(x):
    if 2104 <= x <= 2339: return 1
    elif 2339 <= x <= 2446: return 2
    elif 2446 <= x <= 2579: return 3
    elif 2579 <= x <= 2767: return 4
    else: return 1

def rate_prox_surface(x):  # in meters (distance to surface water)
    if 0 <= x <= 0.022: return 1
    elif 0.023 <= x <= 0.047: return 2
    elif 0.047 <= x <= 0.079: return 3
    elif 0.079 <= x <= 0.145: return 4
    else: return 1

def rate_lineament_density(x):
    if 0 <= x <= 0.090: return 1
    elif 0.090 <= x <= 0.270: return 2
    elif 0.270 <= x <= 0.500: return 3
    elif 0.500 <= x <= 0.860: return 4
    else: return 1


def rate_geology(x):
    # x must already be encoded as numeric values representing geologic types
    geology_ratings = {
        1: 2,  
        2: 3,  
        3: 4,  
        4: 3,  
        5: 1,  
        6: 2,  
        7: 3   
    }
    return geology_ratings.get(int(x), 1)

def rate_drainage_density(x):
    if 0.030 <= x <= 0.750: return 4
    elif 0.750 <= x <= 1.060: return 3
    elif 1.060 <= x <= 1.380: return 2
    elif 1.380 <= x <= 2.330: return 1
    else: return 1

def rate_ndvi(x):
    if 0.0184 <= x <= 0.2684: return 1
    elif 0.2684 <= x <= 0.4723: return 2
    elif 0.4723 <= x <= 0.6993: return 3
    elif 0.6993 <= x <= 0.993: return 4
    else: return 1

def rate_aspect(x):
    # assuming aspect is in degrees: 0–360
    if x == -1: return 4   # North
    elif -1 <= x <= 22.5: return 4             # NE
    elif 22.5 <= x <= 67.5: return 3            # East
    elif 67.5 <= x <= 112.5: return 2            # SE
    elif 112.5 <= x <= 157.5: return 1            # South
    elif 157.5 <= x <= 202.5: return 1            # SW
    elif 202.5 <= x <= 247.5: return 1
    elif 247.5 <= x <= 292.5: return 2             # West
    elif 292.5 <= x <= 337.5: return 3
    elif 337.5 <= x <= 360: return 4
    else: return 1

def rate_slope(x):
    if 0 <= x <= 4.0: return 4
    elif 4.0 <= x <= 10.0: return 3
    elif 10.0 <= x <= 19.0: return 2
    elif 19.0 <= x <= 65: return 1
    else: return 1

# Apply ratings
df['TWI_Rating'] = df['TWI'].apply(rate_twi)
df['Rainfall_Rating'] = df['RAINFALL'].apply(rate_rainfall)
df['ProxSW_Rating'] = df['PTWBDS'].apply(rate_prox_surface)
df['LineamentDensity_Rating'] = df['LD'].apply(rate_lineament_density)
df['Geology_Rating'] = df['GEOLOGY'].apply(rate_geology)
df['DrainageDensity_Rating'] = df['DD'].apply(rate_drainage_density)
df['NDVI_Rating'] = df['NDVI'].apply(rate_ndvi)
df['Aspect_Rating'] = df['ASPT'].apply(rate_aspect)
df['Slope_Rating'] = df['SLOPE'].apply(rate_slope)

# Save output with ratings
df.to_csv("fishnet_rated_output.csv", index=False)
print("✅ Rating complete and saved to 'fishnet_rated_output.csv'")
# Out:
# ✅ Rating complete and saved to 'fishnet_rated_output.csv'

# %%
# generating the AHP final indices

# import the necessary libraries

import pandas as pd
import numpy as np

# Load the ratings data as a csv file

ratings_df = pd.read_csv("criteria_ratings.csv") 

# Use the AHP weights
ahp_weights = np.array([0.10555, 0.17940, 0.06821, 0.17940, 0.27309, 0.10555, 0.04348, 0.02446, 0.02086]) 

# Ensure number of weights matches the number of criteria
if len(ahp_weights) != ratings_df.shape[1]:
    raise ValueError("The number of AHP weights must match the number of criteria in the data.")

# Multiply rating by the corresponding weight
weighted_ratings = ratings_df * ahp_weights

# Calculate the AHP-GP index by summing across the rows
ratings_df['AHP_GP_Index'] = weighted_ratings.sum(axis=1)

# Print the final result
# Step 5: Save the results to a new CSV file
ratings_df.to_csv("ahp_gp_indices.csv", index=False)

print(ratings_df)
# Out:
#      TWI_rating  RAINFALL_rating  PTWBDS_rating  LD_rating  GEOLOGY_rating  \
# 0             4                4              1          1               1
# 1             1                4              2          1               1
# 2             2                4              2          1               1
# 3             2                4              1          1               1
# 4             1                4              1          1               1
# ..          ...              ...            ...        ...             ...
# 220           3                1              1          1               3
# 221           1                1              1          1               3
# 222           2                1              1          1               3
# 223           2                1              2          1               3
# 224           1                1              3          1               3
#
#      DD_rating  NDVI_rating  ASPT_rating  SLOPE_rating  AHP_GP_Index
# 0            1            2            3             4       2.00983
# 1            4            1            4             3       2.03816
# 2            4            2            2             4       2.15913
# 3            4            1            1             3       2.00212
# 4            2            1            1             4       1.70633
# ..         ...          ...          ...           ...           ...
# 220          4            4            3             3       2.29501
# 221          3            3            4             4       1.98020
# 222          3            3            4             4       2.08575
# 223          4            2            2             3       2.14625
# 224          3            4            2             3       2.09032
#
# [225 rows x 10 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import (
    roc_curve, auc, accuracy_score, f1_score,
    classification_report, precision_score, recall_score
)

# Load CSV
df = pd.read_csv("all_ml_models_val_data.csv")

# True labels and number of classes
y_true = df["True_Class"].values
classes = sorted(df["True_Class"].unique())
n_classes = len(classes)

# Binarize true labels for micro-average ROC
y_true_bin = label_binarize(y_true, classes=classes)

# Define models and their probability column patterns
models = {
    "SVM": [f"svm_prob_{i}" for i in classes],
    "RF": [f"rf_prob_{i}" for i in classes],
    "XGBoost": [f"xgb_prob_{i}" for i in classes],
    "AdaBoost": [f"ada_prob_{i}" for i in classes],
    "AHP": None  # special handling for AHP
}

# Store evaluation results
roc_curves = {}
metrics_summary = {}

# Loop through models
for model_name, prob_cols in models.items():
    if model_name != "AHP":
        y_score = df[prob_cols].values
    else:
        # For AHP, repeat the index as a 2D array with shape (n_samples, n_classes)
        y_score = np.tile(df["ahp_index"].values.reshape(-1, 1), (1, n_classes))

    # Compute micro-average ROC
    fpr, tpr, _ = roc_curve(y_true_bin.ravel(), y_score.ravel())
    roc_auc = auc(fpr, tpr)
    roc_curves[model_name] = (fpr, tpr, roc_auc)

    # Compute predicted class
    y_pred = np.argmax(y_score, axis=1)

    # Classification metrics
    metrics_summary[model_name] = {
        "Accuracy": accuracy_score(y_true, y_pred),
        "F1 (macro)": f1_score(y_true, y_pred, average='macro'),
        "Precision (macro)": precision_score(y_true, y_pred, average='macro'),
        "Recall (macro)": recall_score(y_true, y_pred, average='macro'),
    }

# ---------------------------
# 📈 Plot all ROC curves
# ---------------------------
plt.figure(figsize=(8, 6))
for model_name, (fpr, tpr, roc_auc) in roc_curves.items():
    plt.plot(fpr, tpr, lw=2, label=f"{model_name} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], color='grey', lw=1, linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve: ML Models vs AHP")
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()

# ---------------------------
# 📋 Print classification metrics
# ---------------------------
print("\nClassification Performance Metrics (per model):\n")
for model_name, scores in metrics_summary.items():
    print(f"🔹 {model_name}")
    for metric_name, value in scores.items():
        print(f"   {metric_name}: {value:.2f}")
    print()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Performance Metrics (per model):
#
# 🔹 SVM
#    Accuracy: 0.55
#    F1 (macro): 0.53
#    Precision (macro): 0.56
#    Recall (macro): 0.52
#
# 🔹 RF
#    Accuracy: 0.55
#    F1 (macro): 0.55
#    Precision (macro): 0.54
#    Recall (macro): 0.56
#
# 🔹 XGBoost
#    Accuracy: 0.52
#    F1 (macro): 0.51
#    Precision (macro): 0.53
#    Recall (macro): 0.51
#
# 🔹 AdaBoost
#    Accuracy: 0.60
#    F1 (macro): 0.58
#    Precision (macro): 0.57
#    Recall (macro): 0.59
#
# 🔹 AHP
#    Accuracy: 0.27
#    F1 (macro): 0.14
#    Precision (macro): 0.09
#    Recall (macro): 0.33

# %%
# code to compute the statistical analysis of factors

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load your dataset
df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")

# Select only numeric factor columns (exclude target if present)
factor_data = df.select_dtypes(include='number')

# Standardize the factors
scaler = StandardScaler()
scaled_array = scaler.fit_transform(factor_data)

# Create a new DataFrame with scaled data
scaled_df = pd.DataFrame(scaled_array, columns=factor_data.columns)

# Compute statistics on the scaled data
stats_scaled = scaled_df.agg(['min', 'max', 'mean', 'std']).transpose().round(4)

# Save or display the result
print(stats_scaled)
stats_scaled.to_csv("scaled_factor_statistics.csv")
# Out:
#              min     max  mean     std
# TWI      -1.5281  3.9778   0.0  1.0022
# RAINFALL -1.8571  2.5348   0.0  1.0022
# PTWBDS   -1.2952  3.5294  -0.0  1.0022
# LD       -0.3516  4.6987   0.0  1.0022
# GEOLOGY  -1.1543  2.3712  -0.0  1.0022
# DD       -2.0563  2.4129   0.0  1.0022
# NDVI     -1.4706  2.1738   0.0  1.0022
# ASPT     -1.6718  1.8190  -0.0  1.0022
# SLOPE    -0.9750  4.6138   0.0  1.0022

# %%
import pandas as pd

# Load your data
df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")  

# Check if all columns are numeric (important)
df = df.select_dtypes(include='number')

# Compute statistics
stats = df.describe().T[['min', 'max', 'mean', 'std']]

# Optional: Round for cleaner presentation
stats_rounded = stats.round(4)

# Save to CSV
stats_rounded.to_csv("ahp_factors_statistics.csv")

# Display
print(stats_rounded)
# Out:
#                 min        max       mean       std
# TWI          1.2411    11.6099     4.1188    1.8874
# RAINFALL  2160.4600  2756.7500  2412.5950  136.0724
# PTWBDS       0.0000     0.1303     0.0350    0.0271
# LD           0.0000     0.6391     0.0445    0.1268
# GEOLOGY      1.0000     7.0000     2.9644    1.7057
# DD           0.4095     1.8119     1.0547    0.3145
# NDVI         0.0740     0.9412     0.4239    0.2385
# ASPT        -1.0000   354.8060   169.4027  102.1520
# SLOPE        0.3281    28.3888     5.2235    5.0321

# %%
# for the map removal analysis

import pandas as pd
import numpy as np

# Load factor data
df = pd.read_csv("Factr_Fish_Val_Use_New_Crct.csv")  # Each row = location, columns = normalized factors

# Load AHP weights
weights_df = pd.read_csv("ahp_weights.csv")
weights = dict(zip(weights_df['Factor'], weights_df['Weight']))

# Ensure both match
factors = list(weights.keys())
df = df[factors]  # Reorder if needed

# Compute full AHP suitability map
df['AHP_full'] = df.dot([weights[f] for f in factors])

# Store full map for later comparison
full_map = df['AHP_full'].values

# Container for results
sensitivity_results = []

# Loop to remove one factor at a time
for factor_to_remove in factors:
    # Remaining factors and weights
    remaining_factors = [f for f in factors if f != factor_to_remove]
    remaining_weights = [weights[f] for f in remaining_factors]
    
    # Normalize remaining weights
    weight_sum = sum(remaining_weights)
    normalized_weights = [w / weight_sum for w in remaining_weights]
    
    # Recalculate AHP without the removed factor
    partial_map = df[remaining_factors].dot(normalized_weights)
    
    # Calculate absolute and percentage change from full map
    change = np.abs(partial_map - full_map)
    percent_change = (change / full_map) * 100
    
    # Record results
    sensitivity_results.append({
        'Removed_Factor': factor_to_remove,
        'Mean_Abs_Change': round(change.mean(), 4),
        'Max_Abs_Change': round(change.max(), 4),
        'Min_Abs_Change': round(change.min(), 4),
        'Std_Abs_Change': round(change.std(), 4),
        'Mean_%_Change': round(percent_change.mean(), 4)
    })
    
    # Save optional map
    df[f'AHP_without_{factor_to_remove}'] = partial_map

# Save sensitivity results
sensitivity_df = pd.DataFrame(sensitivity_results)
sensitivity_df.to_csv("ahp_map_removal_sensitivity.csv", index=False)

# Save updated AHP maps
df.to_csv("ahp_all_maps.csv", index=False)

# Display summary
print(sensitivity_df)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# === STEP 1: Load data ===
df = pd.read_csv("Factr_Fish_Val_Use_New_Crct_sa.csv")  # Unscaled factor values
weights_df = pd.read_csv("ahp_weights.csv")

# === STEP 2: Extract factors and weights ===
factors = list(weights_df['Factor'])
weights = dict(zip(weights_df['Factor'], weights_df['Weight']))

# Keep only the relevant factor columns in correct order
df = df[factors]

# === STEP 3: Rescale using Min-Max Scaling ===
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=factors)

# === STEP 4: Compute AHP suitability map ===
df_scaled['AHP_full'] = df_scaled.dot([weights[f] for f in factors])
full_map = df_scaled['AHP_full'].values

# === STEP 5: Sensitivity Analysis ===
sensitivity_results = []

for factor_to_remove in factors:
    # Remaining factors and corresponding weights
    remaining_factors = [f for f in factors if f != factor_to_remove]
    remaining_weights = [weights[f] for f in remaining_factors]

    # Renormalize weights
    weight_sum = sum(remaining_weights)
    normalized_weights = [w / weight_sum for w in remaining_weights]

    # Recalculate AHP map without the removed factor
    partial_map = df_scaled[remaining_factors].dot(normalized_weights)

    # Compute differences
    abs_diff = np.abs(partial_map - full_map)
    percent_diff = (abs_diff / full_map) * 100

    sensitivity_results.append({
        'Removed_Factor': factor_to_remove,
        'Mean_Abs_Change': round(abs_diff.mean(), 4),
        'Max_Abs_Change': round(abs_diff.max(), 4),
        'Min_Abs_Change': round(abs_diff.min(), 4),
        'Std_Abs_Change': round(abs_diff.std(), 4),
        'Mean_%_Change': round(percent_diff.mean(), 4)
    })

    # Optional: store the recalculated map for further use
    df_scaled[f"AHP_without_{factor_to_remove}"] = partial_map

# === STEP 6: Save outputs ===
# Save sensitivity results
sensitivity_df = pd.DataFrame(sensitivity_results)
sensitivity_df.to_csv("ahp_sensitivity_analysis_sa.csv", index=False)

# Save all computed maps (original + removed-factor variants)
df_scaled.to_csv("ahp_scaled_and_sensitivity_maps_sa.csv", index=False)

# Display summary
print("\n=== Map Removal Sensitivity Analysis Summary ===")
print(sensitivity_df)
# Out:
# === Map Removal Sensitivity Analysis Summary ===
#   Removed_Factor  Mean_Abs_Change  Max_Abs_Change  Min_Abs_Change  \
# 0            TWI           0.0172          0.0816          0.0000
# 1             RD           0.0358          0.1225          0.0000
# 2            PSW           0.0137          0.0513          0.0000
# 3             LD           0.0647          0.1467          0.0021
# 4             GY           0.0639          0.1845          0.0000
# 5             DD           0.0254          0.0825          0.0003
# 6           NDVI           0.0110          0.0332          0.0001
# 7             AP           0.0069          0.0205          0.0000
# 8             SP           0.0045          0.0163          0.0001
#
#    Std_Abs_Change  Mean_%_Change
# 0          0.0147         5.6305
# 1          0.0293        12.0830
# 2          0.0101         4.6139
# 3          0.0286        21.0451
# 4          0.0420        21.4592
# 5          0.0187         9.5126
# 6          0.0086         3.9813
# 7          0.0050         2.6305
# 8          0.0031         1.4579

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load sensitivity results ===
sensitivity_df = pd.read_csv("ahp_sensitivity_analysis_sa.csv")

# === Bar plot for Mean Absolute Change ===
plt.figure(figsize=(6, 4))
sns.barplot(
    x='Removed_Factor',
    y='Mean_Abs_Change',
    data=sensitivity_df,
    palette='viridis'
)
plt.title('Map Removal Sensitivity: Mean Absolute Change in AHP Score')
plt.ylabel('Mean Absolute Change')
plt.xlabel('Factor Removed')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)
plt.show()

# === (Optional) Plot Mean Percentage Change ===
plt.figure(figsize=(6, 4))
sns.barplot(
    x='Removed_Factor',
    y='Mean_%_Change',
    data=sensitivity_df,
    palette='magma'
)
plt.title('Map Removal Sensitivity: Mean % Change in AHP Score')
plt.ylabel('Mean Percentage Change (%)')
plt.xlabel('Factor Removed')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === Load sensitivity results ===
sensitivity_df = pd.read_csv("ahp_sensitivity_analysis_sa.csv")

# === Bar plot for Mean Absolute Change ===
plt.figure(figsize=(6, 4))
sns.barplot(
    x='Removed_Factor',
    y='Mean_Abs_Change',
    data=sensitivity_df,
    palette='viridis'
)
plt.title('Map Removal Sensitivity: Mean Absolute Change in AHP Score')
plt.ylabel('Mean Absolute Change')
plt.xlabel('Factor Removed')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)

# SAVE the figure in high resolution
plt.savefig("mean_abs_change_sensitivity.png", dpi=600)  # Change to 600 DPI
plt.savefig("mean_abs_change_sensitivity.tiff", dpi=600)  # TIFF is preferred by some journals
plt.show()

# === Plot for Mean Percentage Change ===
plt.figure(figsize=(8, 6))
sns.barplot(
    x='Removed_Factor',
    y='Mean_%_Change',
    data=sensitivity_df,
    palette='magma'
)
plt.title('Map Removal Sensitivity: Mean % Change in AHP Score')
plt.ylabel('Mean Percentage Change (%)')
plt.xlabel('Factor Removed')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)

# SAVE this one too
plt.savefig("mean_percentage_change_sensitivity.png", dpi=800)
plt.savefig("mean_percentage_change_sensitivity.tiff", dpi=800)
plt.show()
